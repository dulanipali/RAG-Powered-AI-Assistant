# %%
from dotenv import load_dotenv 
load_dotenv()
import os
from openai import OpenAI
from pinecone import Pinecone, ServerlessSpec

# %%
# Initialize Pinecone
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
pc.create_index(name="rag", dimension=1536, metric="cosine", spec=ServerlessSpec(cloud="aws", region="us-east-1"))

# Create a Pinecone index
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Initialize Pinecone
#       2 pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
# ----> 3 pc.create_index(name="rag", dimension=1536, metric="cosine", spec=ServerlessSpec(cloud="aws", region="us-east-1"))
#       5 # Create a Pinecone index
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/control/pinecone.py:384, in Pinecone.create_index(self, name, dimension, spec, metric, timeout, deletion_protection)
#     381 else:
#     382     raise TypeError("spec must be of type dict, ServerlessSpec, or PodSpec")
# --> 384 api_instance.create_index(
#     385     create_index_request=CreateIndexRequest(
#     386         name=name,
#     387         dimension=dimension,
#     388         metric=metric,
#     389         spec=index_spec,
#     390         deletion_protection=dp,
#     391     ),
#     392 )
#     394 def is_ready():
#     395     status = self._get_status(name)
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:761, in Endpoint.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     """This method is invoked when endpoints are called
#     752     Example:
#     753
#    (...)
#     759
#     760     """
# --> 761     return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/control/api/manage_indexes_api.py:273, in ManageIndexesApi.__init__.<locals>.__create_index(self, create_index_request, **kwargs)
#     271 kwargs["_host_index"] = kwargs.get("_host_index")
#     272 kwargs["create_index_request"] = create_index_request
# --> 273 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:819, in Endpoint.call_with_http_info(self, **kwargs)
#     816     header_list = self.api_client.select_header_content_type(content_type_headers_list)
#     817     params["header"]["Content-Type"] = header_list
# --> 819 return self.api_client.call_api(
#     820     self.settings["endpoint_path"],
#     821     self.settings["http_method"],
#     822     params["path"],
#     823     params["query"],
#     824     params["header"],
#     825     body=params["body"],
#     826     post_params=params["form"],
#     827     files=params["file"],
#     828     response_type=self.settings["response_type"],
#     829     auth_settings=self.settings["auth"],
#     830     async_req=kwargs["async_req"],
#     831     _check_type=kwargs["_check_return_type"],
#     832     _return_http_data_only=kwargs["_return_http_data_only"],
#     833     _preload_content=kwargs["_preload_content"],
#     834     _request_timeout=kwargs["_request_timeout"],
#     835     _host=_host,
#     836     collection_formats=params["collection_format"],
#     837 )
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:380, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     326 """Makes the HTTP request (synchronous) and returns deserialized data.
#     327
#     328 To make an async_req request, set the async_req parameter.
#    (...)
#     377     then the method will return the response directly.
#     378 """
#     379 if not async_req:
# --> 380     return self.__call_api(
#     381         resource_path,
#     382         method,
#     383         path_params,
#     384         query_params,
#     385         header_params,
#     386         body,
#     387         post_params,
#     388         files,
#     389         response_type,
#     390         auth_settings,
#     391         _return_http_data_only,
#     392         collection_formats,
#     393         _preload_content,
#     394         _request_timeout,
#     395         _host,
#     396         _check_type,
#     397     )
#     399 return self.pool.apply_async(
#     400     self.__call_api,
#     401     (
#    (...)
#     418     ),
#     419 )
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:187, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
# --> 187     raise e
#     189 self.last_response = response_data
#     191 return_data = response_data
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:175, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     171     url = _host + resource_path
#     173 try:
#     174     # perform request and return response
# --> 175     response_data = self.request(
#     176         method,
#     177         url,
#     178         query_params=query_params,
#     179         headers=header_params,
#     180         post_params=post_params,
#     181         body=body,
#     182         _preload_content=_preload_content,
#     183         _request_timeout=_request_timeout,
#     184     )
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:460, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     450     return self.rest_client.OPTIONS(
#     451         url,
#     452         query_params=query_params,
#    (...)
#     457         body=body,
#     458     )
#     459 elif method == "POST":
# --> 460     return self.rest_client.POST(
#     461         url,
#     462         query_params=query_params,
#     463         headers=headers,
#     464         post_params=post_params,
#     465         _preload_content=_preload_content,
#     466         _request_timeout=_request_timeout,
#     467         body=body,
#     468     )
#     469 elif method == "PUT":
#     470     return self.rest_client.PUT(
#     471         url,
#     472         query_params=query_params,
#    (...)
#     477         body=body,
#     478     )
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/rest.py:345, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     335 def POST(
#     336     self,
#     337     url,
#    (...)
#     343     _request_timeout=None,
#     344 ):
# --> 345     return self.request(
#     346         "POST",
#     347         url,
#     348         headers=headers,
#     349         query_params=query_params,
#     350         post_params=post_params,
#     351         _preload_content=_preload_content,
#     352         _request_timeout=_request_timeout,
#     353         body=body,
#     354     )
#
# File ~/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/rest.py:279, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     276     if 500 <= r.status <= 599:
#     277         raise ServiceException(http_resp=r)
# --> 279     raise PineconeApiException(http_resp=r)
#     281 return r
#
# PineconeApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'access-control-allow-origin': '*', 'vary': 'origin,access-control-request-method,access-control-request-headers', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2024-07', 'X-Cloud-Trace-Context': '23c24b385c745538fad7b537ebdfbc69', 'Date': 'Sun, 25 Aug 2024 07:00:00 GMT', 'Server': 'Google Frontend', 'Content-Length': '85', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"ALREADY_EXISTS","message":"Resource  already exists"},"status":409}

# %%
import json
data=json.load(open("reviews.json")) # Load the review data
data['reviews']
# Out:
# [{'professor': 'Dr. Alice Johnson',
#   'subject': 'Computer Science',
#   'stars': 4,
#   'review': 'Great at explaining complex concepts, but her exams are tough.'},
#  {'professor': 'Dr. Mark Evans',
#   'subject': 'Mathematics',
#   'stars': 5,
#   'review': 'Very engaging lectures and always willing to help during office hours.'},
#  {'professor': 'Dr. Lisa Wong',
#   'subject': 'Physics',
#   'stars': 3,
#   'review': 'Interesting lectures but sometimes hard to follow.'},
#  {'professor': 'Dr. Kevin Patel',
#   'subject': 'Chemistry',
#   'stars': 4,
#   'review': 'He knows his stuff but expects students to be self-driven.'},
#  {'professor': 'Dr. Susan Brown',
#   'subject': 'Biology',
#   'stars': 5,
#   'review': 'Passionate about the subject, makes learning fun and interactive.'},
#  {'professor': 'Dr. Robert Adams',
#   'subject': 'History',
#   'stars': 3,
#   'review': 'A bit dry at times, but knowledgeable and fair in grading.'},
#  {'professor': 'Dr. Emily Taylor',
#   'subject': 'Economics',
#   'stars': 4,
#   'review': 'Clear and concise teaching, but the material is challenging.'},
#  {'professor': 'Dr. James Green',
#   'subject': 'Political Science',
#   'stars': 5,
#   'review': 'Engaging lectures and open to diverse viewpoints.'},
#  {'professor': 'Dr. Nancy White',
#   'subject': 'Psychology',
#   'stars': 4,
#   'review': 'Really cares about students, though her grading is strict.'},
#  {'professor': 'Dr. Michael Clark',
#   'subject': 'Sociology',
#   'stars': 2,
#   'review': 'Lectures can be monotonous, and the assignments are tedious.'},
#  {'professor': 'Dr. Karen Scott',
#   'subject': 'Philosophy',
#   'stars': 5,
#   'review': 'Brilliant and thought-provoking. Makes you think deeply about life.'},
#  {'professor': 'Dr. Richard Lewis',
#   'subject': 'Anthropology',
#   'stars': 3,
#   'review': 'Content is interesting, but the exams are very difficult.'},
#  {'professor': 'Dr. Patricia Martin',
#   'subject': 'English Literature',
#   'stars': 4,
#   'review': 'Encourages creativity and critical thinking, but readings are heavy.'},
#  {'professor': 'Dr. William Harris',
#   'subject': 'Statistics',
#   'stars': 3,
#   'review': 'Explains well, but you need to put in extra effort to succeed.'},
#  {'professor': 'Dr. Linda King',
#   'subject': 'Environmental Science',
#   'stars': 5,
#   'review': 'Passionate about the environment and makes the subject come alive.'},
#  {'professor': 'Dr. George Robinson',
#   'subject': 'Art History',
#   'stars': 4,
#   'review': 'Very knowledgeable but sometimes gets sidetracked in lectures.'},
#  {'professor': 'Dr. Jessica Hill',
#   'subject': 'Linguistics',
#   'stars': 4,
#   'review': 'Really knows her field, but expects a lot from students.'},
#  {'professor': 'Dr. Daniel Carter',
#   'subject': 'Geography',
#   'stars': 2,
#   'review': 'Not very engaging, and the material can be dry.'},
#  {'professor': 'Dr. Amanda Parker',
#   'subject': 'Philosophy',
#   'stars': 5,
#   'review': 'Inspires deep thinking and is very approachable.'},
#  {'professor': 'Dr. Charles Thompson',
#   'subject': 'Computer Engineering',
#   'stars': 4,
#   'review': 'Good balance of theory and practical work, but assignments are tough.'}]

# %%
processed_data = []
client = OpenAI()

# Create embeddings for each review
for review in data['reviews']:
    response = client.embeddings.create(
        input=review['review'], #Takes each review in reviews
        model="text-embedding-3-small"
    )
    embedding = response.data[0].embedding
    processed_data.append(
        {
            "values": embedding,
            "id": review["professor"],
            "metadata":{
                "review": review["review"],
                "subject": review["subject"],
                "stars": review["stars"],
            }
        }
    )

# %%
processed_data[0]
# Out:
# {'values': [-0.013750226,
#   -0.030419335,
#   0.039548,
#   0.00278832,
#   0.031420913,
#   0.011596835,
#   -0.009693838,
#   0.041608386,
#   0.0039383452,
#   0.013242284,
#   0.0057340306,
#   -0.016640492,
#   -0.016282786,
#   -0.04916314,
#   -0.015882155,
#   -0.0055158297,
#   -0.038002707,
#   -0.03136368,
#   0.010910039,
#   0.011146125,
#   0.037945475,
#   -0.0049435,
#   0.039061517,
#   0.02539714,
#   0.016282786,
#   -0.02541145,
#   0.031563997,
#   0.011904462,
#   0.046215642,
#   0.029288985,
#   0.08235828,
#   -0.019502142,
#   0.031821545,
#   -0.041637003,
#   -0.028058475,
#   0.067191534,
#   0.003374958,
#   0.04238103,
#   0.038517803,
#   0.0145157175,
#   -0.0060130414,
#   0.05414241,
#   -0.04481343,
#   -0.01254118,
#   0.051652774,
#   0.013371058,
#   -0.06787833,
#   -0.030819967,
#   0.018843964,
#   0.037344526,
#   -0.058377653,
#   0.046158407,
#   0.04469897,
#   0.009207358,
#   -0.04272443,
#   -0.00014207643,
#   0.014200936,
#   0.0056267185,
#   0.003974116,
#   -0.01968815,
#   0.04281028,
#   -0.027514761,
#   0.013678685,
#   -0.009686684,
#   -0.050365034,
#   -0.034253947,
#   0.008556332,
#   -0.021219132,
#   -0.04409802,
#   -0.018400406,
#   0.013142126,
#   0.021834387,
#   -0.03771654,
#   -0.0124911005,
#   0.03511244,
#   0.006746339,
#   0.022692882,
#   0.001683902,
#   -0.01013024,
#   -0.02066111,
#   -0.020804193,
#   -0.012870269,
#   0.01928752,
#   0.007490368,
#   0.03436841,
#   0.011933079,
#   -0.017198514,
#   -0.030419335,
#   -0.022335175,
#   -0.04641596,
#   -0.015896464,
#   0.028874045,
#   -0.025654688,
#   0.0021802194,
#   -0.003489424,
#   -0.014351173,
#   0.004464173,
#   0.014723187,
#   -0.053312533,
#   -0.007383056,
#   0.0062670126,
#   0.0076334504,
#   -0.00011094481,
#   0.007898153,
#   0.08785264,
#   0.0040098866,
#   -0.06621857,
#   -0.024295405,
#   -0.06335692,
#   -0.03951938,
#   -0.07491799,
#   -0.02662765,
#   0.0033839007,
#   -0.019502142,
#   -0.056746513,
#   -0.03242249,
#   0.02541145,
#   0.043554306,
#   0.03588509,
#   0.04040649,
#   0.036056787,
#   -0.0004967645,
#   0.0011142548,
#   0.009729609,
#   0.00398127,
#   -0.002586216,
#   -0.0076262965,
#   0.028187249,
#   -0.025382832,
#   0.039261833,
#   -0.0043032058,
#   0.010623874,
#   0.023594301,
#   0.0012439233,
#   0.022564108,
#   0.02981839,
#   0.008191472,
#   0.023579992,
#   0.020804193,
#   -0.012348019,
#   0.005519407,
#   -0.06318522,
#   0.024381256,
#   0.00096759526,
#   0.010895731,
#   0.022077627,
#   -0.0044498653,
#   0.013986313,
#   0.028215865,
#   -0.0011884789,
#   -0.016139705,
#   0.005762647,
#   -0.013020506,
#   -0.0047002593,
#   0.05537292,
#   -0.0049113063,
#   -0.028029859,
#   -0.012469638,
#   0.0048540733,
#   -0.022764422,
#   -0.00437117,
#   0.0017527604,
#   0.012183473,
#   0.024681728,
#   0.037458993,
#   -0.031048898,
#   0.021934545,
#   -0.014093624,
#   0.006968117,
#   0.024324022,
#   -0.010173164,
#   0.025182517,
#   -0.016812192,
#   -0.017942544,
#   0.043582924,
#   0.008956963,
#   0.0046287184,
#   0.008263013,
#   0.00651383,
#   0.014809037,
#   0.034511495,
#   -0.008069852,
#   -0.018572107,
#   0.043897707,
#   -0.036457416,
#   -0.0048826896,
#   -0.012526872,
#   0.017913926,
#   0.018815346,
#   -0.037859626,
#   0.029188827,
#   -0.0014800094,
#   0.017541911,
#   0.038975667,
#   -0.00021507086,
#   0.017255748,
#   -0.02368015,
#   0.0020764845,
#   0.04246688,
#   0.034625962,
#   0.004020618,
#   0.00018466583,
#   -0.015181052,
#   -0.025869314,
#   -0.044384185,
#   -0.012526872,
#   -0.0043926323,
#   -0.013778843,
#   -0.04109329,
#   -0.046272874,
#   0.004099313,
#   0.032794505,
#   0.038231637,
#   0.026770731,
#   -0.0041279295,
#   -0.023665842,
#   0.03740176,
#   0.014072162,
#   0.021791462,
#   -0.0041780085,
#   0.025983779,
#   0.01715559,
#   0.009872692,
#   0.0364288,
#   0.028330332,
#   0.0020979468,
#   0.020031547,
#   -0.004557177,
#   0.007561909,
#   0.0011384,
#   -0.027800927,
#   -0.023622917,
#   0.0034411338,
#   -0.007036081,
#   -0.031420913,
#   -0.002124775,
#   -0.019130128,
#   -0.035226908,
#   -0.036400184,
#   -0.012476793,
#   ...],
#  'id': 'Dr. Alice Johnson',
#  'metadata': {'review': 'Great at explaining complex concepts, but her exams are tough.',
#   'subject': 'Computer Science',
#   'stars': 4}}

# %%
# Insert the embeddings into the Pinecone index
index = pc.Index("rag")
upsert_response = index.upsert(
    vectors=processed_data,
    namespace="ns1",
)

# %%
print(f"Upserted count: {upsert_response['upserted_count']}")

# Print index statistics
print(index.describe_index_stats())
# Out:
# Upserted count: 20
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'ns1': {'vector_count': 20}},
#  'total_vector_count': 20}
